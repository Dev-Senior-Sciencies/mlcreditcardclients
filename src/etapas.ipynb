# %% [markdown]
# O que quero prever?
# Como a probabilidade de inadimplência do cliente se ele vai pagar a fatura do cartão de credito baseado no historico da conta
# Classe → Classificação

# %% [markdown]
# Tenho rótulos?
# Sim → Supervisionado
#
# ID : Identificação de cada cliente
# LIMIT_BAL : Valor do crédito concedido em dólares taiwaneses (inclui crédito individual e familiar/suplementar).
# SEXO : Gênero (1=masculino, 2=feminino)
# FORMAÇÃO ACADÊMICA : (1=pós-graduação, 2=universidade, 3=ensino médio, 4=outros, 5=desconhecido, 6=desconhecido)
# CASAMENTO : Estado civil (1=casado(a), 2=solteiro(a), 3=outros)
# IDADE : Idade em anos
# PAY_0 : Situação do pagamento em setembro de 2005 (-1 = pagamento em dia, 1 = atraso de um mês, 2 = atraso de dois meses, ..., 8 = atraso de oito meses, 9 = atraso de nove meses ou mais)
# PAY_2 : Situação do pagamento em agosto de 2005 (escala igual à anterior)
# PAY_3 : Situação do pagamento em julho de 2005 (escala igual à anterior)
# PAY_4 : Situação do pagamento em junho de 2005 (escala igual à anterior)
# PAY_5 : Situação do pagamento em maio de 2005 (escala igual à anterior)
# PAY_6 : Situação do pagamento em abril de 2005 (escala igual à anterior)
# BILL_AMT1 : Valor da fatura de setembro de 2005 (em dólares de NT)
# BILL_AMT2 : Valor da fatura em agosto de 2005 (dólar NT)
# BILL_AMT3 : Valor da fatura de julho de 2005 (em dólares taiwaneses)
# BILL_AMT4 : Valor da fatura em junho de 2005 (dólar NT)
# BILL_AMT5 : Valor da fatura de maio de 2005 (em dólares de NT)
# BILL_AMT6 : Valor da fatura de abril de 2005 (em dólares de NT)
# PAY_AMT1 : Valor do pagamento anterior em setembro de 2005 (dólar NT)
# PAY_AMT2 : Valor do pagamento anterior em agosto de 2005 (dólar NT)
# PAY_AMT3 : Valor do pagamento anterior em julho de 2005 (dólar NT)
# PAY_AMT4 : Valor do pagamento anterior em junho de 2005 (dólar NT)
# PAY_AMT5 : Valor do pagamento anterior em maio de 2005 (dólar NT)
# PAY_AMT6 : Valor do pagamento anterior em abril de 2005 (dólar NT)
# default.payment.next.month : Pagamento padrão (1=sim, 0=não)

# %% [markdown]
# ETAPA 2 — ENTENDER OS DADOS
#
# SEX: Gender (1=male, 2=female)
# EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# MARRIAGE: Marital status (1=married, 2=single, 3=others)
#
# AGE: Age in years
#
# PAY_0 : Situação do pagamento em setembro de 2005 (-1 = pagamento em dia, 1 = atraso de um mês, 2 = atraso de dois meses, ..., 8 = atraso de oito meses, 9 = atraso de nove meses ou mais)

# %% [markdown]
# 🔹 ETAPA 3 — ESCOLHER O MODELO (REGRA DE OURO)
#
# 4️⃣ Alta performance
#
# ✅ Gradient Boosting
#
# XGBoost / LightGBM / CatBoost
#
# 📌 Regra prática:
#
# Se for Kaggle ou produção → Gradient Boosting ganha quase sempre.

# %% [markdown]
# 🔹 ETAPA 4 — PRÉ-PROCESSAMENTO
#
# Checklist padrão:
#
# Valores nulos
#
# Outliers
#
# Encoding:
#
# One-Hot
#
# Scaling:
#
# StandardScaler
#
# Split:
#
# Train / Validation / Test

# %% [markdown]
# 🔹 ETAPA 5 — TREINAMENTO
#
# Sempre:
#
# Começar simples
#
# Métrica correta
#
# Cross-validation
#
# Ajustar hiperparâmetros depois

# %% [markdown]
# 🔹 ETAPA 6 — AVALIAÇÃO
#
# Escolha certa da métrica:
#
# Problema	Métrica
# Classificação	Accuracy, F1
# Desbalanceado	Precision / Recall
